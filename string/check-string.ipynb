# %%
str = "This is a string"
print("is" in str) # returns True if present
# Out:
# True

# %%
print("BCD" in str)
# Out:
# False

# %%
my_string = "This is a sample string"
print("super" not in my_string)
# Out:
# True

# %%
print("sample" not in my_string)
# Out:
# False
