# %%
str = "Alik"
print(str[0]) # prints character of index 0
# Out:
# A

# %%
print(str[1]) # prints character of index 1
# Out:
# l

# %%
print(str[3]) # prints character of index 3
# Out:
# k

# %%
print(str[4]) # index out of bound
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(str[4])
#
# IndexError: string index out of range
