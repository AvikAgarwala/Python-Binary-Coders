# %%
a = 5
b = 3

# %%
if a > b:
    print("A is greater")
    print("Hello")
else: # if the 'if' block becomes false
    print("B is greater")
    print("Bye")
# Out:
# A is greater
# Hello

# %%
c = 3
d = 5

# %%
if c > d:
    print("C is greater")
    print("Hello")
else:
    print("D is greater")
    print("Bye")
# Out:
# D is greater
# Bye
