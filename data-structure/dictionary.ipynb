# %%
student = {12 : "Avik", 75 : "Alik", 49 : "Pritam"}
print(student)
# Out:
# {12: 'Avik', 75: 'Alik', 49: 'Pritam'}

# %%
print(student[49])
# Out:
# Pritam

# %%
student[75] = "Ankika"
student[75]
# Out:
# 'Ankika'

# %%
d = {12 : "Avik", True : 49}
student[True]
# Out:
# 'Avik'

# %%
d.get(12)
# Out:
# 'Avik'
